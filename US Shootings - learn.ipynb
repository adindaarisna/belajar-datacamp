# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dfx = pd.read_csv('shootings.csv')
dfx
# Out:
#         id                              name        date   manner_of_death  \
# 0        3                        Tim Elliot  2015-01-02              shot
# 1        4                  Lewis Lee Lembke  2015-01-02              shot
# 2        5                John Paul Quintero  2015-01-03  shot and Tasered
# 3        8                   Matthew Hoffman  2015-01-04              shot
# 4        9                 Michael Rodriguez  2015-01-04              shot
# 5       11                 Kenneth Joe Brown  2015-01-04              shot
# 6       13               Kenneth Arnold Buck  2015-01-05              shot
# 7       15                     Brock Nichols  2015-01-06              shot
# 8       16                     Autumn Steele  2015-01-06              shot
# 9       17                   Leslie Sapp III  2015-01-06              shot
# 10      19                    Patrick Wetter  2015-01-06  shot and Tasered
# ...

# %%
#zero indexing
df = pd.read_csv('shootings.csv', index_col=0)
df.head()
# Out:
#                   name        date   manner_of_death       armed   age gender  \
# id
# 3           Tim Elliot  2015-01-02              shot         gun  53.0      M
# 4     Lewis Lee Lembke  2015-01-02              shot         gun  47.0      M
# 5   John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0      M
# 8      Matthew Hoffman  2015-01-04              shot  toy weapon  32.0      M
# 9    Michael Rodriguez  2015-01-04              shot    nail gun  39.0      M
#
#         race           city state  signs_of_mental_illness threat_level  \
# id
# 3      Asian        Shelton    WA                     True       attack
# 4      White          Aloha    OR                    False       attack
# 5   Hispanic        Wichita    KS                    False        other
# 8      White  San Francisco    CA                     True       attack
# 9   Hispanic          Evans    CO                    False       attack
#
#            flee  body_camera          arms_category
# ...

# %%
df['name'].head()
# Out:
# id
# 3            Tim Elliot
# 4      Lewis Lee Lembke
# 5    John Paul Quintero
# 8       Matthew Hoffman
# 9     Michael Rodriguez
# Name: name, dtype: object

# %%
#multiple columns selction
df[['name', 'gender']].head()
# Out:
#                   name gender
# id
# 3           Tim Elliot      M
# 4     Lewis Lee Lembke      M
# 5   John Paul Quintero      M
# 8      Matthew Hoffman      M
# 9    Michael Rodriguez      M

# %%
# df.loc[['name', 'gender']] <---- this will turn error
df.loc[:, ['name', 'gender']].head()
# Out:
#                   name gender
# id
# 3           Tim Elliot      M
# 4     Lewis Lee Lembke      M
# 5   John Paul Quintero      M
# 8      Matthew Hoffman      M
# 9    Michael Rodriguez      M

# %%
df.sort_values('age', ascending=False)
# Out:
#                        name        date   manner_of_death            armed  \
# id
# 2407        Frank W. Wratny  2017-03-08              shot              gun
# 5609  Lawson Edward Schaber  2020-03-08              shot              gun
# 4100           Kay Kenniker  2018-10-12              shot              gun
# 4252    Amelia Huron-Macias  2018-03-07              shot          unarmed
# 3403         Raymond Bishop  2018-02-12              shot              gun
# 357     Richard Dale Weaver  2015-04-12              shot          machete
# 2095       Quinton Phillips  2016-12-01              shot              gun
# 2653     Theodore Brendecke  2017-06-09              shot              gun
# 1822         Darrel Hetrick  2016-08-27              shot              gun
# 3578         Robert Litolff  2018-04-05              shot              gun
# 1621        Edward Acquisto  2016-06-13              shot              gun
# ...

# %%
df.sort_values(['age', 'name'], ascending=[False, True])
# Out:
#                            name        date   manner_of_death  \
# id
# 2407            Frank W. Wratny  2017-03-08              shot
# 4252        Amelia Huron-Macias  2018-03-07              shot
# 4100               Kay Kenniker  2018-10-12              shot
# 5609      Lawson Edward Schaber  2020-03-08              shot
# 3403             Raymond Bishop  2018-02-12              shot
# 2095           Quinton Phillips  2016-12-01              shot
# 357         Richard Dale Weaver  2015-04-12              shot
# 1822             Darrel Hetrick  2016-08-27              shot
# 2653         Theodore Brendecke  2017-06-09              shot
# 3578             Robert Litolff  2018-04-05              shot
# 1621            Edward Acquisto  2016-06-13              shot
# 4431                Robert Matz  2019-02-04              shot
# 2524              Robert Becker  2017-04-24              shot
# 3402              John Hamilton  2018-02-09              shot
# ...

# %%
df[df['race']=='Black']
# Out:
#                                   name        date   manner_of_death  \
# id
# 17                     Leslie Sapp III  2015-01-06              shot
# 21                           Ron Sneed  2015-01-07              shot
# 22      Hashim Hanif Ibn Abdul-Rasheed  2015-01-07              shot
# 27    Omarr Julian Maximillian Jackson  2015-01-07              shot
# 36                 Artago Damon Howard  2015-01-08              shot
# 49                       Marcus Golden  2015-01-14              shot
# 51                        Mario Jordan  2015-01-14              shot
# 56                        Donte Sowell  2015-01-15              shot
# 57                 Kavonda Earl Payton  2015-01-15              shot
# 74                      Terence Walker  2015-01-17              shot
# 85                        Dewayne Carr  2015-01-20              shot
# 90                        Isaac Holmes  2015-01-21              shot
# ...

# %%
df[(df['date']>='2019-1-1')]
# Out:
#                                name        date   manner_of_death  \
# id
# 5072             Jack Thomas Naylor  2019-10-01              shot
# 5073                     Roy Tucker  2019-10-01              shot
# 5074                    Joseph Jesk  2019-10-01              shot
# 5081          Christopher G. Louras  2019-10-01              shot
# 5082                   Michael John  2019-10-03              shot
# 5079            Bruce William Clark  2019-10-04              shot
# 5080             Christopher Massey  2019-10-05              shot
# 5078                Antonio Vasquez  2019-10-06              shot
# 5088                 Maurice Holley  2019-10-06              shot
# 5085            Joshua Chase Conner  2019-10-07              shot
# 5475               Bobby Lee Vaughn  2019-10-07              shot
# 5086               Crederick Joseph  2019-10-08              shot
# 5087                  Joseph Cimino  2019-10-08              shot
# ...

# %%
#subsetting based on multiple conditions
ismale = df['gender'] == 'M'
isfemale = df['gender'] == 'F'
isblack = df['race'] == 'Black'
iswhite = df['race'] == 'White'
ismental = df['signs_of_mental_illness'] == True
df[ismale & isblack & ismental]
# Out:
#                                 name        date   manner_of_death  \
# id
# 22    Hashim Hanif Ibn Abdul-Rasheed  2015-01-07              shot
# 51                      Mario Jordan  2015-01-14              shot
# 107                   Darin Hutchins  2015-01-24              shot
# 339            Edward Donnell Bright  2015-01-31  shot and Tasered
# 119             Dewayne Deshawn Ward  2015-02-03              shot
# 141                  Phillip Watkins  2015-02-11              shot
# 150                      Lavall Hall  2015-02-15  shot and Tasered
# 255                   Douglas Harris  2015-02-20              shot
# 191                      Ian Sherrod  2015-02-28              shot
# 194           Charly Leundeu Keunang  2015-03-01  shot and Tasered
# 200          Tyrone Ryerson Lawrence  2015-03-05              shot
# 205                     Anthony Hill  2015-03-09              shot
# 282                      Bobby Gross  2015-03-12              shot
# ...

# %%
#subsetting using .isin()
df[df['race'].isin(['Black', 'white'])]
# Out:
#                                   name        date   manner_of_death  \
# id
# 17                     Leslie Sapp III  2015-01-06              shot
# 21                           Ron Sneed  2015-01-07              shot
# 22      Hashim Hanif Ibn Abdul-Rasheed  2015-01-07              shot
# 27    Omarr Julian Maximillian Jackson  2015-01-07              shot
# 36                 Artago Damon Howard  2015-01-08              shot
# 49                       Marcus Golden  2015-01-14              shot
# 51                        Mario Jordan  2015-01-14              shot
# 56                        Donte Sowell  2015-01-15              shot
# 57                 Kavonda Earl Payton  2015-01-15              shot
# 74                      Terence Walker  2015-01-17              shot
# 85                        Dewayne Carr  2015-01-20              shot
# 90                        Isaac Holmes  2015-01-21              shot
# ...

# %%
blkage = df[df['race']=='Black']['age'].mean()
print('Age average of black persons: ', blkage)
# Out:
# Age average of black persons:  32.54994633407771

# %%
df[df['race']=='Black'].count()
# Out:
# name                       1298
# date                       1298
# manner_of_death            1298
# armed                      1298
# age                        1298
# gender                     1298
# race                       1298
# city                       1298
# state                      1298
# signs_of_mental_illness    1298
# threat_level               1298
# flee                       1298
# body_camera                1298
# arms_category              1298
# dtype: int64

# %%
df.groupby('race')['age'].mean()
# Out:
# race
# Asian       36.561676
# Black       32.549946
# Hispanic    33.683847
# Native      31.732281
# Other       33.064957
# White       39.909488
# Name: age, dtype: float64

# %%
df.groupby('race')['age'].agg([min, max])
# Out:
#            min   max
# race
# Asian     15.0  62.0
# Black     13.0  77.0
# Hispanic  14.0  80.0
# Native    14.0  58.0
# Other     18.0  59.0
# White      6.0  91.0

# %%
df.groupby(['race', 'signs_of_mental_illness'])['age'].count()
# Out:
# race      signs_of_mental_illness
# Asian     False                        69
#           True                         24
# Black     False                      1114
#           True                        184
# Hispanic  False                       745
#           True                        157
# Native    False                        64
#           True                         14
# Other     False                        37
#           True                         11
# White     False                      1763
#           True                        713
# Name: age, dtype: int64

# %%
df.groupby(['signs_of_mental_illness', 'race'])['age'].count()
# Out:
# signs_of_mental_illness  race
# False                    Asian         69
#                          Black       1114
#                          Hispanic     745
#                          Native        64
#                          Other         37
#                          White       1763
# True                     Asian         24
#                          Black        184
#                          Hispanic     157
#                          Native        14
#                          Other         11
#                          White        713
# Name: age, dtype: int64

# %%
df.groupby(['signs_of_mental_illness'])['age'].count()
# Out:
# signs_of_mental_illness
# False    3792
# True     1103
# Name: age, dtype: int64

# %%
#---- group by pivot table
df.pivot_table(values='age', index='race')
# Out:
#                 age
# race
# Asian     36.561676
# Black     32.549946
# Hispanic  33.683847
# Native    31.732281
# Other     33.064957
# White     39.909488

# %%
# hasilnya sama dengan saat menggunakan pivot table
df.groupby('race')['age'].mean()
# Out:
# race
# Asian       36.561676
# Black       32.549946
# Hispanic    33.683847
# Native      31.732281
# Other       33.064957
# White       39.909488
# Name: age, dtype: float64

# %% [markdown]
# ### Visualizing the shooting data

# %%
df['age'].hist(bins=10)
plt.show()

# %%
df['age'].plot(kind='hist', bins=20, title='Sum Shooting Victims by Age')
plt.show()

# %%
df.columns
# Out:
# Index(['name', 'date', 'manner_of_death', 'armed', 'age', 'gender', 'race',
#        'city', 'state', 'signs_of_mental_illness', 'threat_level', 'flee',
#        'body_camera', 'arms_category'],
#       dtype='object')

# %%
df.race.unique()
# Out:
# array(['Asian', 'White', 'Hispanic', 'Black', 'Other', 'Native'],
#       dtype=object)

# %%
x=list(df.race.unique())
print(x)
print(len(x))
# Out:
# ['Asian', 'White', 'Hispanic', 'Black', 'Other', 'Native']
# 6

# %%
#count the amount of row by name column
df.groupby('race')['name'].count()
# Out:
# race
# Asian         93
# Black       1298
# Hispanic     902
# Native        78
# Other         48
# White       2476
# Name: name, dtype: int64

# %%
#count the amount of row by gender column
df.groupby('race')['gender'].count()
# Out:
# race
# Asian         93
# Black       1298
# Hispanic     902
# Native        78
# Other         48
# White       2476
# Name: gender, dtype: int64

# %%
countbyrace = df.groupby('race')['gender'].count()
countbyrace.plot(kind='bar', title='Count by Race', rot=25)
plt.show()
print('COUNT BY RACE\n',countbyrace)
# Out:
# COUNT BY RACE
#  race
# Asian         93
# Black       1298
# Hispanic     902
# Native        78
# Other         48
# White       2476
# Name: gender, dtype: int64

# %%
df20 = df[(df['date']>'2020') & (df['date']<'2021')]
df19 = df[(df['date']>'2019') & (df['date']<'2020')]
df18 = df[(df['date']>'2018') & (df['date']<'2019')]

print(df20.groupby('race')['name'].count())
print(df19.groupby('race')['name'].count())
# Out:
# race
# Asian         8
# Black       103
# Hispanic     63
# Native        3
# Other         3
# White       194
# Name: name, dtype: int64
# race
# Asian        19
# Black       250
# Hispanic    163
# Native       13
# Other         9
# White       404
# Name: name, dtype: int64

# %%
df20 = df[(df['date']>'2020') & (df['date']<'2021')]
df19 = df[(df['date']>'2019') & (df['date']<'2020')]
df18 = df[(df['date']>'2018') & (df['date']<'2019')]

datadf20 = df20.groupby('race')['name'].count()
datadf20.plot(kind='bar', title='', rot=25)
plt.show()

# %%
datadf19 = df19.groupby('race')['name'].count()
datadf19.plot(kind='bar', title='', rot=25, color='green', alpha=0.5)
plt.show()

# %%
datadf18 = df18.groupby('race')['name'].count()
datadf18.plot(kind='bar', title='', rot=25)
plt.show()

# %%
df20 = df[(df['date']>'2020') & (df['date']<'2021')]
df19 = df[(df['date']>'2019') & (df['date']<'2020')]
df18 = df[(df['date']>'2018') & (df['date']<'2019')]

datadf20 = df20.groupby('race')['name'].count()
datadf19 = df19.groupby('race')['name'].count()
datadf18 = df18.groupby('race')['name'].count()
datadf20.plot(kind='bar', title='Count by Race', rot=25, color='green', alpha=0.4)
datadf19.plot(kind='bar', title='Count by Race', rot=25, color='red', alpha=0.4)
datadf18.plot(kind='bar', title='Count by Race', rot=25, color='blue', alpha=0.4)
plt.show()
#but this presentation is not pretty

# %%
#turn date into datetime so that the year can be extracted using method dt.year
df['datetime']=pd.to_datetime(df['date'])

# %%
#insert new column 'year' that contain year extraction from datetime
df['year']=df['datetime'].dt.year

# %%
df.head()
# Out:
#                   name        date   manner_of_death       armed   age gender  \
# id
# 3           Tim Elliot  2015-01-02              shot         gun  53.0      M
# 4     Lewis Lee Lembke  2015-01-02              shot         gun  47.0      M
# 5   John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0      M
# 8      Matthew Hoffman  2015-01-04              shot  toy weapon  32.0      M
# 9    Michael Rodriguez  2015-01-04              shot    nail gun  39.0      M
#
#         race           city state  signs_of_mental_illness threat_level  \
# id
# 3      Asian        Shelton    WA                     True       attack
# 4      White          Aloha    OR                    False       attack
# 5   Hispanic        Wichita    KS                    False        other
# 8      White  San Francisco    CA                     True       attack
# 9   Hispanic          Evans    CO                    False       attack
#
# ...

# %%
asian = df[df['race']=='Asian'].groupby(df['year']).count()
asian = list(asian)

print(asian)
# Out:
# ['name', 'date', 'manner_of_death', 'armed', 'age', 'gender', 'race', 'city', 'state', 'signs_of_mental_illness', 'threat_level', 'flee', 'body_camera', 'arms_category', 'datetime', 'year']

# %%
df[df['race']=='Asian'].groupby(df['year']).count()
# Out:
#       name  date  manner_of_death  armed  age  gender  race  city  state  \
# year
# 2015    14    14               14     14   14      14    14    14     14
# 2016    15    15               15     15   15      15    15    15     15
# 2017    16    16               16     16   16      16    16    16     16
# 2018    21    21               21     21   21      21    21    21     21
# 2019    19    19               19     19   19      19    19    19     19
# 2020     8     8                8      8    8       8     8     8      8
#
#       signs_of_mental_illness  threat_level  flee  body_camera  arms_category  \
# year
# 2015                       14            14    14           14             14
# 2016                       15            15    15           15             15
# 2017                       16            16    16           16             16
# 2018                       21            21    21           21             21
# ...

# %%
data = df[df['race']=='Asian'].groupby(df['year']).count()
data['name']
data['year']
#data.plot(kind='line', )
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'index'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-6af36dd30fab> in <module>
# ...
